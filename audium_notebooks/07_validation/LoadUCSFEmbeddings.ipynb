# %%
import numpy as np

# Load the .npz file
loaded = np.load("/Users/abelvillcaroque/git/github/audiumhealth/hear/audium_notebooks/audium_UCSF_embeddings.npz", allow_pickle=False)

# Convert back to a dictionary
file_embeddings = {key: loaded[key] for key in loaded.files}

print(f"✅ Loaded {len(file_embeddings)} embeddings from .npz")
# Out:
# ✅ Loaded 19484 embeddings from .npz

# %%
import numpy as np

# Load the file
data = np.load("/Users/abelvillcaroque/git/github/audiumhealth/hear/audium_notebooks/audium_UCSF_embeddings.npz")

# See the first N keys (filenames)
N = 20
print("First keys:", data.files[:N])

# View shape or content of first few arrays
for key in data.files[:N]:
    arr = data[key]
    print(f"\n🔹 {key}: shape={arr.shape}, dtype={arr.dtype}")
    print(arr if arr.size < 10 else arr[:2])  # preview only first 2 rows if large
# Out:
# First keys: ['R2D202272/Lung-LeftLateralInfraScapularPosterior-N1vSYj_jSBZ6TbbOOSE.wav', 'R2D202272/Lung-RightInterScapularPosterior-N1vS8Fc0_IcuzBHHJIO.wav', 'R2D202272/Lung-RightLateralInfraScapularPosterior-N1vSeDnv1QVQAVfVvRu.wav', 'R2D202272/Lung-RightInfraClavicularAnterior-N1vRFB6Dy_0yYnGvC8V.wav', 'R2D202272/Lung-LeftInfraScapularPosterior-N1vSM75j9I3s6eprIEO.wav', 'R2D202272/Lung-LeftSuprascapularPosterior-N1vRs09m2NCLDYrc7lV.wav', 'R2D202272/Lung-LeftInterScapularPosterior-N1vSErUeSoPs3QmOx99.wav', 'R2D202272/Lung-LeftInfraAxillaryPosterior-N1vSrDBKE8eAT7N7RAK.wav', 'R2D202272/Lung-RightAxillaryPosterior-N1vT43wicIouJ7L9loG.wav', 'R2D202272/Lung-RightMammaryAnterior-N1vRT9XKLG_Pm14AD1S.wav', 'R2D202272/Lung-LeftMammaryAnterior-N1vRZU3RoLdrvFxYeGN.wav', 'R2D202272/Lung-RightInfraScapularPosterior-N1vSSOMk0C1wpk4oSs2.wav', 'R2D202272/Lung-LeftAxillaryPosterior-N1vSkVU5E1sji9svqJI.wav', 'R2D202272/Lung-RightSuprascapularPosterior-N1vS14pB4t3bxbaxruA.wav', 'R2D202272/Lung-Right
# ...
